# %%
import pandas as pd
import snowflake.connector
import os
from dotenv import load_dotenv
import matplotlib as plt

# %%
load_dotenv()

conn = snowflake.connector.connect(
    account=os.getenv("SNOWFLAKE_ACCOUNT"),
    user=os.getenv("SNOWFLAKE_USER"),
    password=os.getenv("SNOWFLAKE_PASSWORD"),
    warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
    database=os.getenv("SNOWFLAKE_DATABASE"),
    schema=os.getenv("SNOWFLAKE_SCHEMA_TRANSFORMED"),
)

query = """
    SELECT * 
    FROM FACT_LOANS l
    LEFT JOIN DIM_FRED_MACRO_INDICATORS f
    ON l.LOAN_ISSUE_DATE = f.DATE
"""

df = pd.read_sql(query, conn)
conn.close()
# Out:
# C:\Users\bmass\AppData\Local\Temp\ipykernel_15864\109271651.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df = df[df['LOAN_STATUS'].isin(['Fully Paid', 'Charged Off'])]
df['target'] = (df['LOAN_STATUS'] == 'Charged Off').astype(int) # Charged Off = 1, Fully Paid = 0
print(df.columns.tolist())

# %%
columns = df.columns.tolist()

for col in columns:
    pct = df[col].isnull().mean() * 100
    print(f"{col:45s} {pct:.2f}%")
# Out:
# LOAN_ID                                       0.00%
# LOAN_STATUS                                   0.00%
# LOAN_ISSUE_DATE                               0.00%
# LOAN_AMOUNT                                   0.00%
# LOAN_TERM                                     0.00%
# LOAN_INTEREST_RATE                            0.00%
# LOAN_INSTALLMENT                              0.00%
# LOAN_PURPOSE                                  0.00%
# LOAN_EMP_LENGTH                               5.84%
# LOAN_HOME_OWNERSHIP                           0.00%
# LOAN_ANNUAL_INCOME                            0.00%
# LOAN_APPLICATION_TYPE                         0.00%
# LOAN_ADDR_STATE                               0.00%
# LOAN_DTI                                      0.03%
# LOAN_FICO_RANGE_LOW                           0.00%
# LOAN_FICO_RANGE_HIGH                          0.00%
# LOAN_EARLIEST_CR_LINE                         0.00%
# LOAN_OPEN_ACC                                 0.00%
# LOAN_TOTAL_ACC                                0.00%
# LOAN_REVOL_BAL                                0.00%
# LOAN_REVOL_UTIL                               0.06%
# LOAN_TOTAL_REV_HI_LIM                         5.02%
# LOAN_DELINQ_2YRS                              0.00%
# LOAN_MTHS_SINCE_LAST_DELINQ                   50.45%
# LOAN_MTHS_SINCE_LAST_RECORD                   83.01%
# LOAN_PUB_REC                                  0.00%
# LOAN_PUB_REC_BANKRUPTCIES                     0.05%
# LOAN_ACC_NOW_DELINQ                           0.00%
# LOAN_TAX_LIENS                                0.00%
# LOAN_INQ_LAST_6MTHS                           0.00%
# LOAN_TOT_CUR_BAL                              5.02%
# LOAN_TOT_COLL_AMT                             5.02%
# LOAN_TOT_HI_CRED_LIM                          5.02%
# LOAN_TOTAL_BAL_EX_MORT                        3.51%
# LOAN_TOTAL_BC_LIMIT                           3.51%
# LOAN_AVG_CUR_BAL                              5.02%
# LOAN_MORT_ACC                                 3.51%
# LOAN_BC_UTIL                                  4.60%
# LOAN_BC_OPEN_TO_BUY                           4.54%
# LOAN_PERCENT_BC_GT_75                         4.58%
# LOAN_NUM_ACCTS_EVER_120_PD                    5.02%
# LOAN_PCT_TL_NVR_DLQ                           5.03%
# DATE                                          0.00%
# UNEMPLOYMENT_RATE                             0.00%
# GDP                                           0.00%
# FEDERAL_FUNDS_RATE                            0.00%
# CONSUMER_PRICE_INDEX                          0.00%
# FIXED_MORTGAGE_RATE                           0.00%
# PERSONAL_SAVINGS_RATE                         0.00%
# target                                        0.00%
